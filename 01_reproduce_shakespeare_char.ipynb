# %%
# %cd /content
![ -d nanoGPT ] || git clone https://github.com/karpathy/nanoGPT.git
# %cd nanoGPT
# !python data/shakespeare_char/prepare.py
# !python train.py config/train_shakespeare_char.py
# Out:
# /content
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 689, done.
# remote: Total 689 (delta 0), reused 0 (delta 0), pack-reused 689 (from 1)
# Receiving objects: 100% (689/689), 981.25 KiB | 3.70 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# /content/nanoGPT
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens
# Overriding config with config/train_shakespeare_char.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-shakespeare-char'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# ...

# %%
# %cd /content/nanoGPT
# !python sample.py --out_dir=out-shakespeare-char
# Out:
# /content/nanoGPT
# Overriding: out_dir = out-shakespeare-char
# number of parameters: 10.65M
# Loading meta from data/shakespeare_char/meta.pkl...
#
#
# Clown:
# Ready, will you not say a serious business?
#
# AUTOLYCUS:
#
# Clown:
# Your unquit is back: let me saw your honour's wife,
# be not some formicial. Hark you, sir, if ever
# you that Hercules that Baptista's piteous spelling, and
# the service of the princess, why he shall not
# do't, and who thinks the parteous provost, evil seems
# to our fair enforces of the shoot.
#
# ANGELO:
# Here's such a great shame in all of all first: go home,
# Her such as you are as a man as he may in company,
# And I would have forgot
# ---------------
#
# Menenius, and such a fellow me master
# Be his own officers, which he was not been to live.
#
# MENENIUS:
# Why, you shall show to tial we have stuff'd
# With when moves: if you cannot speak of their soul
# What the gods as you come, she speaks him in Rome,
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

# make a project folder in your Google Drive (safe to re-run)
os.makedirs('/content/drive/MyDrive/nanogpt-shakespeare-study', exist_ok=True)

# copy the trained model checkpoint folder into Drive
shutil.copytree(
    '/content/nanoGPT/out-shakespeare-char',
    '/content/drive/MyDrive/nanogpt-shakespeare-study/baseline-out-shakespeare-char',
    dirs_exist_ok=True
)

print("✅ Saved to Drive. Contents:")
print(os.listdir('/content/drive/MyDrive/nanogpt-shakespeare-study/baseline-out-shakespeare-char'))
# Out:
# ✅ Saved to Drive. Contents:
# ['ckpt.pt']
